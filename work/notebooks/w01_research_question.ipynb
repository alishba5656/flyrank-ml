# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### My Lane
#
# I choose the **SEO Performance Prediction** lane because it focuses on understanding which web pages are likely to perform better in search results. This project can help identify pages that may need optimization and support better SEO decisions. I selected this lane because it combines data analysis with machine learning and has practical value for improving website performance.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Research Question
#
# **Research Question:** Can machine learning predict whether a web page is likely to achieve better search performance?
#
# **Unit of Analysis:** Individual web page.
#
# **Output:** A prediction of whether a page is likely to perform well in search results.
#
# **Decision:** Decide which pages should be optimized first.
#
# **Action:** Improve content, SEO, or page quality for pages predicted to perform poorly.
#
# **Cost of a Wrong Recommendation:** If the prediction is incorrect, time and resources may be spent optimizing the wrong pages while important pages are ignored.
#
# **Why ML?** Machine learning can discover patterns from multiple features that are difficult to identify manually.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### Careful Words
#
# This analysis identifies patterns in the available dataset. It does not prove causation or guarantee future outcomes. The predictions are intended to support decision-making and should be validated with additional data and testing.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# - [x] Every section is completed.
# - [x] I used careful language.
# - [x] I included supporting data.
# - [x] My work focuses on a decision, not only on training a model.
