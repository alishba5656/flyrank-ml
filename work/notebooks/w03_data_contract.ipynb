# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print(df.head())
# Out:
# Rows: 30000
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ### Unit of Analysis
#
# - One row represents one content page with its SEO metrics.
# - The analysis is performed on the anonymized content refresh dataset.
# - I use the available historical data instead of future observations.
# - The goal is to identify pages that need SEO improvements.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
features = [
    "ctr",
    "avg_position",
    "search_volume",
    "engagement_rate",
    "word_count"
]

label = "trend_direction"

context = [
    "content_type",
    "main_intent"
]

excluded = [
    "content_id",
    "client_id"
]

print("Features:",features)
print("Label:",label)
print("Context:",context)
print("Excluded:",excluded)
# Out:
# Features: ['ctr', 'avg_position', 'search_volume', 'engagement_rate', 'word_count']
# Label: trend_direction
# Context: ['content_type', 'main_intent']
# Excluded: ['content_id', 'client_id']

# %% [markdown]
# ### Data Fields
#
# **Features**
#
# - CTR
# - Average Position
# - Search Volume
# - Engagement Rate
# - Word Count
#
# **Label**
#
# - Trend Direction
#
# **Context**
#
# - Content Type
# - Main Intent
#
# **Excluded**
#
# - Content ID
# - Client ID
#
# These identifiers are excluded because they do not help the model learn useful patterns.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
print("Shape")
print(df.shape)

print("\nColumns")
print(df.columns)

print("\nMissing Values")
print(df.isnull().sum())
# Out:
# Shape
# (30000, 44)
#
# Columns
# Index(['content_id', 'client_id', 'search_volume', 'competition',
#        'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count',
#        'char_count', 'provider_used', 'model_used', 'impressions_90d',
#        'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d',
#        'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d',
#        'days_with_impressions', 'days_with_sessions', 'impressions_last_30d',
#        'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d',
#        'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier',
#        'age_tier_order', 'days_since_last_update', 'freshness_tier',
#        'word_count_tier', 'char_count_tier', 'ctr', 'avg_position',
#        'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier',
#        'position_tier', 'trend_direction', 'trend_pct'],
#       dtype='object')
#
# Missing Values
# content_id                    0
# ...

# %% [markdown]
# ### Verification
#
# The dataset contains one row per content page.
#
# The selected features are available before making an optimization decision.
#
# Some columns contain missing values, so preprocessing will be required before modeling.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
print("CTR Mean:",df["ctr"].mean())

print("Average Position:",df["avg_position"].mean())

print("Search Volume:",df["search_volume"].mean())
# Out:
# CTR Mean: 0.5107333333333334
# Average Position: 16.342380000000002
# Search Volume: 158.88239139909922

# %% [markdown]
# ### Data Limitations
#
# This dataset is anonymized and does not include every factor affecting search performance.
#
# External events, Google algorithm updates, and seasonal effects cannot be captured completely.
#
# Therefore, the analysis shows patterns rather than proving causation.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# - [x] Unit of analysis defined
#
# - [x] Features identified
#
# - [x] Label selected
#
# - [x] Context fields documented
#
# - [x] Excluded fields documented
#
# - [x] Verification queries executed
#
# - [x] Data limitations explained

# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
import os

for root, dirs, files in os.walk("data"):
    for file in files:
        print(os.path.join(root, file))

# %%
# !git clone https://github.com/alishba5656/flyrank-ml.git
# %cd /content/flyrank-ml
# Out:
# Cloning into 'flyrank-ml'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 105 (delta 23), reused 80 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (105/105), 1.82 MiB | 21.91 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/flyrank-ml
